# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips);

# %%
sns.barplot(x="sex", y="total_bill", data=tips);

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x='total_bill',y='tip',data=tips)
ax.set(xlabel='Total Bill', ylabel='Tip', title='Some title')
#plt.legend(labels=['legend1'])
plt.show()

# %%
sns.scatterplot(x="total_bill", y="tip", hue="sex", style="smoker", data=tips);

# %%
sns.scatterplot(x="total_bill", y="tip", hue="sex", style="smoker", data=tips, s=120);
# s büyüklüklerini ayarlar.

# %%
sns.scatterplot(x="total_bill", y="tip", hue="sex", style="smoker", data=tips, size="size");

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x="total_bill", y="tip", hue="sex", style="smoker", data=tips, s=120);

# %%
# 1 satır 2 sutun :
fig, ((axes1, axes2)) = plt.subplots(nrows=1, ncols=2, figsize=(12,6))
axes1 = sns.scatterplot(x="total_bill", y="tip", hue="sex", data=tips, s=120);
axes2 = sns.scatterplot(x="total_bill", y="tip",  hue="smoker", data=tips, s=120);
plt.tight_layout(pad=5)
plt.show()

# %%
sns.rugplot(x=tips["total_bill"]);

# %%
sns.rugplot(x="total_bill", data=tips, height=0.2);

# %%
sns.displot(x="total_bill", data=tips, kde=True);
# en fazla 20 dolat ödenmiş.

# %%
sns.histplot(x=df["tip"], kde=True);
# en fazla 2-4 dolar arası bahşiş verilmiş.

# %%
sns.set(style="whitegrid");
sns.histplot(x=df["tip"], kde=True);

# %%
sns.displot(data=tips, x="total_bill", bins=20, kde=False, color="red", edgecolor='black',lw=4,ls='--');

# %%
sns.kdeplot(x="total_bill", data=tips);

# %%
sns.kdeplot(x="total_bill", data=tips, clip=[10,20]);
# 10 and 20

# %%
sns.kdeplot(x="total_bill", data=tips, bw_adjust= 0.2);
# dalgalamalı olarak görmek istersek

# %%
sns.kdeplot(x="total_bill", data=tips, shade=True, color="red");

# %%
data = pd.DataFrame(np.random.normal(0,1,size=(100,2)),columns=['x','y'])
sns.kdeplot(data=data, x="x", y="y", shade=True, color="red", cbar=True);
